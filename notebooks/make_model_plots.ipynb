# %%
from src.efficientUNet.model.efficient_unet import build_efficient_unet
# this script needs currently to be in the baes folder of the 'package'
import keras

# %%
name = 'l'
m = build_efficient_unet(name, (256,256,3))
keras.utils.plot_model(model=m, to_file=('./model_plot_images/model_plot_' + name + '.png'), show_shapes=True)
